# %%
import polars as pl

# %%
df = pl.read_csv("feature_description.csv", separator=";")

# %%
df.head()
# Out:
# shape: (5, 7)
# ┌───────────────┬──────────────┬──────────────┬──────────────┬──────────────┬──────────────┬───────┐
# │ Feature       ┆ Feature Area ┆ Feature name ┆ Name in      ┆ Function     ┆ Description  ┆ Notes │
# │ ---           ┆ ---          ┆ ---          ┆ extracted    ┆ ---          ┆ ---          ┆ ---   │
# │ str           ┆ str          ┆ str          ┆ dataframe    ┆ str          ┆ str          ┆ str   │
# │               ┆              ┆              ┆ ---          ┆              ┆              ┆       │
# │               ┆              ┆              ┆ str          ┆              ┆              ┆       │
# ╞═══════════════╪══════════════╪══════════════╪══════════════╪══════════════╪══════════════╪═══════╡
# │ Raw sequence  ┆ surface      ┆ raw_sequence ┆ raw_sequence ┆ get_raw_sequ ┆ Number of    ┆ null  │
# │ length/total  ┆              ┆ _length      ┆ _length      ┆ ence_length  ┆ characters   ┆       │
# ...

# %%
df.write_csv("feature_description.csv", separator=",")
